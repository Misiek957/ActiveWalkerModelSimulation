# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from PIL import Image
import cv2
# %matplotlib inline

im = Image.open("cc_fin_new_hill.bmp")
# im = Image.open("cc_fin.bmp")
im2 = mpimg.imread('cc_fin.bmp')
im3 = cv2.imread('cc_fin_grad.bmp')
print(im3.shape)
# Out:
# (505, 447, 3)

# %%
Base = np.array(im)
Nx = Base[:,0,0].size  # N appears to be resolution
Ny = Base[0,:,0].size  # Nx,Ny is size, Nz is RGB level
# g_grad=np.zeros((Nx,Ny))  # initialise an empty matrix
g_height=np.array(np.float64(Base[:,:,2]))# blue channel
g_grad = np.gradient(g_height,1)
g_grad_xy = g_grad[0] + g_grad[1]

# %%
plt.imshow(g_height)

# %%
plt.imshow(g_grad[0]) # [0] - gradient along vertical

# %%
plt.imshow(g_grad[1]) # [1] - gradient along horizontal

# %%
b = im3.copy()
# set green and red channels to 0
# plt.imshow(b[:,:,0])
b[:, :, 1] = 0
b[:, :, 2] = 0
blueCh = np.array(b)
bGrad = np.gradient(blueCh)
# print(blueCh)
plt.imshow(b)
# cv2.imshow('B-RGB', b)

# %%
g = im3.copy()
# set blue and red channels to 0
g[:, :, 0] = 0
g[:, :, 2] = 0
plt.imshow(g)
# cv2.imshow('G-RGB', g)

# %%
r = im3.copy()
# set blue and green channels to 0
r[:, :, 0] = 0
r[:, :, 1] = 0
plt.imshow(r)
# cv2.imshow('R-RGB', r)
